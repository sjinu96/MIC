# %% [markdown]
# # Resnet vs Densenet

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ex_root = '../XTransformer/experiments/x_transformer_pair_dense_x2_CheXpert_fc'

one_dense = pd.read_csv(os.path.join(ex_root, 'log.csv'))

# %%
aa

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))
one_dense.drop(['Epoch'], axis=1).plot(ax=ax)

plt.savefig('dense.png')

# %%
ex_root = '../XTransformer/experiments/xtransformer_pair'

one_dense = pd.read_csv(os.path.join(ex_root, 'log.csv'))

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))
one_dense.drop(['Epoch'], axis=1).plot(ax=ax)

plt.savefig('res.png')

# %% [markdown]
# # ImageNet vs CheXpert

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ex_root = '../XTransformer/experiments/x_transformer_pair_dense_x2_CheXpert_fc'

one_dense = pd.read_csv(os.path.join(ex_root, 'log.csv'))

# %%
aa

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))
one_dense.drop(['Epoch'], axis=1).plot(ax=ax)

plt.savefig('dense.png')
